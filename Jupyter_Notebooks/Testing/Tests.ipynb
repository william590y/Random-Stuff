# %%
from scipy.stats import *
import numpy as np
import matplotlib.pyplot as plt
f = lambda x: norm(1,2).cdf(x)
x = np.linspace(-10,10,1000)
plt.plot(x,f(x))
plt.show()

# %%
norm.std()
norm.mean()
# Out:
# 0.0
